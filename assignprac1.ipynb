# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datas = pd.read_csv("Downloads\dataset_Facebook (1).csv")
datas
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# 1. Perform the following operations using Python on the Facebook metrics data sets<br>
#     a. Create data subsets <br>
# 	b. Merge Data<br>
# 	c. Sort Data<br>
# 	d. Transposing Data<br>
# 	e. Shape and reshape Data<br>

# %%
datas.shape
# Out:
# (500, 19)

# %%
datas.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
datas.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
datas.shape
# Out:
# (500, 19)

# %%
datas.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
datas = datas.dropna()
datas
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
datas.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data_subc1 = datas[["Type","Category","Post Month","Post Weekday"]]
data_subc1
# Out:
#        Type  Category  Post Month  Post Weekday
# 0     Photo         2          12             4
# 1    Status         2          12             3
# 2     Photo         3          12             3
# 3     Photo         2          12             2
# 4     Photo         2          12             2
# ..      ...       ...         ...           ...
# 494   Photo         3           1             7
# 495   Photo         3           1             7
# 496   Photo         2           1             5
# 497   Photo         1           1             5
# 498   Photo         3           1             4
#
# [495 rows x 4 columns]

# %%
data_subc2 = datas[["Post Hour","Lifetime Post Consumers"]]
data_subc2
# Out:
#      Post Hour  Lifetime Post Consumers
# 0            3                      109
# 1           10                     1361
# 2            3                      113
# 3           10                      790
# 4            3                      410
# ..         ...                      ...
# 494         10                      756
# 495          2                      708
# 496          8                      508
# 497          2                      572
# 498         11                      574
#
# [495 rows x 2 columns]

# %%
data_subr1 = datas[["Page total likes","Type","Category"]].loc[0:20]
data_subr1
# Out:
#     Page total likes    Type  Category
# 0             139441   Photo         2
# 1             139441  Status         2
# 2             139441   Photo         3
# 3             139441   Photo         2
# 4             139441   Photo         2
# 5             139441  Status         2
# 6             139441   Photo         3
# 7             139441   Photo         3
# 8             139441  Status         2
# 9             139441   Photo         3
# 10            139441  Status         2
# 11            139441   Photo         2
# 12            139441   Photo         2
# 13            139441   Photo         2
# 14            138414   Photo         2
# 15            138414  Status         2
# 16            138414   Photo         3
# 17            138414   Photo         1
# 18            138414  Status         3
# 19            138414   Photo         3
# 20            138414   Photo         2

# %%
data_subr2 = datas[["Page total likes","Type","Category"]].loc[21:50]
data_subr2
# Out:
#     Page total likes    Type  Category
# 21            138414   Photo         1
# 22            138414    Link         1
# 23            138414   Photo         3
# 24            138414  Status         2
# 25            138458  Status         2
# 26            138458  Status         2
# 27            138458   Photo         3
# 28            138895   Photo         2
# 29            138895   Video         1
# 30            138895   Photo         2
# 31            138895   Photo         2
# 32            138895   Photo         3
# 33            138895   Photo         3
# 34            138895   Photo         1
# 35            138895   Photo         2
# 36            138895   Photo         3
# 37            138895   Photo         1
# 38            138895  Status         2
# 39            138895   Photo         1
# 40            138895  Status         2
# 41            138895    Link         1
# 42            138353   Photo         1
# 43            138353    Link         1
# ...

# %%
data_row1 = datas.iloc[[1,2,5,7,9,10]]
data_row1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 5             139441  Status         2          12             1          9
# 7             139441   Photo         3          12             7          9
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 2    0.0                       2413                             4373
# 5    0.0                      10472                            20849
# 7    1.0                      13720                            24137
# 9    0.0                       4694                             8668
# ...

# %%
data_row2 = datas.iloc[[2,5,6,8,12,14,18]]
data_row2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2             139441   Photo         3          12             3          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 8             139441  Status         2          12             7          3
# 12            139441   Photo         2          12             5         10
# 14            138414   Photo         2          12             4          5
# 18            138414  Status         3          12             2          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2    0.0                       2413                             4373
# 5    0.0                      10472                            20849
# 6    1.0                      11692                            19479
# 8    0.0                      11844                            22538
# ...

# %%
m1 = pd.concat([data_subc1,data_subc2])
m1
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  \
# 0     Photo       2.0        12.0           4.0        NaN
# 1    Status       2.0        12.0           3.0        NaN
# 2     Photo       3.0        12.0           3.0        NaN
# 3     Photo       2.0        12.0           2.0        NaN
# 4     Photo       2.0        12.0           2.0        NaN
# ..      ...       ...         ...           ...        ...
# 494     NaN       NaN         NaN           NaN       10.0
# 495     NaN       NaN         NaN           NaN        2.0
# 496     NaN       NaN         NaN           NaN        8.0
# 497     NaN       NaN         NaN           NaN        2.0
# 498     NaN       NaN         NaN           NaN       11.0
#
#      Lifetime Post Consumers
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 494                    756.0
# ...

# %%
m2 = pd.concat([data_subr1,data_subr2])
m2
# Out:
#     Page total likes    Type  Category
# 0             139441   Photo         2
# 1             139441  Status         2
# 2             139441   Photo         3
# 3             139441   Photo         2
# 4             139441   Photo         2
# 5             139441  Status         2
# 6             139441   Photo         3
# 7             139441   Photo         3
# 8             139441  Status         2
# 9             139441   Photo         3
# 10            139441  Status         2
# 11            139441   Photo         2
# 12            139441   Photo         2
# 13            139441   Photo         2
# 14            138414   Photo         2
# 15            138414  Status         2
# 16            138414   Photo         3
# 17            138414   Photo         1
# 18            138414  Status         3
# 19            138414   Photo         3
# 20            138414   Photo         2
# 21            138414   Photo         1
# 22            138414    Link         1
# ...

# %%
m3 = data_row1.merge(data_row2)
m3
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         3          12             3          3
# 1            139441  Status         2          12             1          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2413                             4373
# 1   0.0                      10472                            20849
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     177                      113
# 1                    1191                     1073
#
#    Lifetime Post Consumptions  \
# 0                         154
# 1                        1389
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               2812
# 1                                              16034
#
#    Lifetime Post reach by people who like your Page  \
# ...

# %%
str1 = m2.sort_values(by="Category")
str1
# Out:
#     Page total likes    Type  Category
# 49            138353    Link         1
# 34            138895   Photo         1
# 37            138895   Photo         1
# 22            138414    Link         1
# 39            138895   Photo         1
# 21            138414   Photo         1
# 29            138895   Video         1
# 41            138895    Link         1
# 43            138353    Link         1
# 44            138353   Photo         1
# 45            138353    Link         1
# 46            138353  Status         1
# 47            138353    Link         1
# 48            138353   Photo         1
# 42            138353   Photo         1
# 17            138414   Photo         1
# 26            138458  Status         2
# 28            138895   Photo         2
# 0             139441   Photo         2
# 31            138895   Photo         2
# 35            138895   Photo         2
# 40            138895  Status         2
# 30            138895   Photo         2
# ...

# %%
str2 = datas.transpose()
str2
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
print(str1.shape)
# Out:
# (51, 3)

# %%
str2.shape
# Out:
# (19, 495)

# %%
m2.shape
# Out:
# (51, 3)

# %%
reshape = str1.melt(id_vars="Type", value_vars=["Category","Page total likes"])
reshape
# Out:
#        Type          variable   value
# 0      Link          Category       1
# 1     Photo          Category       1
# 2     Photo          Category       1
# 3      Link          Category       1
# 4     Photo          Category       1
# ..      ...               ...     ...
# 97   Status  Page total likes  138414
# 98    Photo  Page total likes  138414
# 99    Photo  Page total likes  138458
# 100   Photo  Page total likes  139441
# 101   Photo  Page total likes  138414
#
# [102 rows x 3 columns]

# %%
reshape.shape
# Out:
# (102, 3)
